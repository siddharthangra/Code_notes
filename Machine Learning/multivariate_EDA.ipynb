# %%
import pandas as pd
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
tips.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 26        13.37  2.00    Male     No   Sat  Dinner     2
# 133       12.26  2.00  Female     No  Thur   Lunch     2
# 206       26.59  3.41    Male    Yes   Sat  Dinner     3
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 20        17.92  4.08    Male     No   Sat  Dinner     2

# %%
titanic = pd.read_csv(r"C:\Users\SIDDHARTH\OneDrive\Documents\JOB PROFILES\Data Science\Machine Learning\data files\titanic.csv")

# %%
flights = sns.load_dataset('flights')

# %%
iris = sns.load_dataset('iris')

# %% [markdown]
# ## Bivariate analysis

# %% [markdown]
# #### Scatterplot (numerical-numerical)

# %%
sns.scatterplot(x = tips['total_bill'], y = tips['tip'], hue = tips['sex'], style= tips['smoker'], size = tips['size'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# #### Bar plot (numerical-categorical)

# %%
titanic.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 410          411         0       3
# 17            18         1       2
# 186          187         1       3
# 423          424         0       3
# 522          523         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 410                                 Sdycoff, Mr. Todor    male   NaN      0
# 17                        Williams, Mr. Charles Eugene    male   NaN      0
# 186    O'Brien, Mrs. Thomas (Johanna "Hannah" Godfrey)  female   NaN      1
# 423  Danbom, Mrs. Ernst Gilbert (Anna Sigrid Maria ...  female  28.0      1
# 522                                 Lahoud, Mr. Sarkis    male   NaN      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 410      0  349222   7.8958   NaN        S
# 17       0  244373  13.0000   NaN        S
# 186      0  370365  15.5000   NaN        Q
# 423      1  347080  14.4000   NaN        S
# 522      0    2624   7.2250   NaN        C

# %%
sns.barplot(x = titanic['Pclass'],y=  titanic['Fare'], hue = titanic['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>
